# %%
# !git clone https://github.com/Armanfard-Lab/DCSS.git
# Out:
# Cloning into 'DCSS'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 70 (delta 18), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (70/70), 3.14 MiB | 5.83 MiB/s, done.

# %%
# %cd /content/DCSS/Codes
# Out:
# /content/DCSS/Codes

# %%
# !python train.py
# Out:
# ...
# 100% 9912422/9912422 [00:00<00:00, 83705047.67it/s]
# Extracting /home/mrsadeghi/Spectral_clustering_network/MNIST/raw/train-images-idx3-ubyte.gz to /home/mrsadeghi/Spectral_clustering_network/MNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 21125862.19it/s]
# Extracting /home/mrsadeghi/Spectral_clustering_network/MNIST/raw/train-labels-idx1-ubyte.gz to /home/mrsadeghi/Spectral_clustering_network/MNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 21251613.71it/s]
# Extracting /home/mrsadeghi/Spectral_clustering_network/MNIST/raw/t10k-images-idx3-ubyte.gz to /home/mrsadeghi/Spectral_clustering_network/MNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 30143241.72it/s]
# Extracting /home/mrsadeghi/Spectral_clustering_network/MNIST/raw/t10k-labels-idx1-ubyte.gz to /home/mrsadeghi/Spectral_clustering_network/MNIST/raw
#
# -----initialization mode--------
# ...
